# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import classification_report, f1_score
from catboost import CatBoostClassifier

# Function to load data and split into features and target
def load_data(file_path, target_columns, selected_features):
    data = pd.read_csv(file_path)
    X = data[selected_features]
    y = data[target_columns]
    return X, y

# Function to initialize CatBoost classifier within a MultiOutputClassifier
def initialize_catboost():
    return MultiOutputClassifier(
        CatBoostClassifier(
            verbose=50,
            random_state=42,
            early_stopping_rounds=20
        )
    )

# Main workflow
target_columns_clusters = [f"Cluster{i}" for i in range(6)]
selected_features_updated = [
    "Time_Period", "Stn Press (kPa)", "Dew Point Temp (°C)", "Rel Hum (%)",
    "Visibility (km)", "Temp (°C)", "Wind Dir (10s deg)", "Wind Spd (km/h)",
    "C0D-1HA", "C0D-2HA", "C0D-4HA",  # Cluster 0 historical features
    "C1D-1HA", "C1D-2HA", "C1D-4HA",  # Cluster 1 historical features
    "C2D-1HA", "C2D-2HA", "C2D-3HA",  # Cluster 2 historical features
    "C3D-1HA", "C4D-1HA", "C4D-2HA", "C5D-1HA"  # Other cluster features
]
file_path = 'xydata_2021winter.csv'

# Load the data and split
X, y = load_data(file_path, target_columns_clusters, selected_features_updated)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train the model
catboost_model = initialize_catboost()

# Define a simpler hyperparameter grid
# param_grid = {
#     'estimator__learning_rate': [0.025, 0.05, 0.75],
#     'estimator__depth': [7, 8, 9],
#     'estimator__iterations': [50, 100, 300],
#     'estimator__scale_pos_weight': [7, 5, 10],
#     'estimator__l2_leaf_reg': [2, 3, 4]
# }
# Best parameters: {'estimator__depth': 7, 'estimator__iterations': 300, 'estimator__l2_leaf_reg': 2, 'estimator__learning_rate': 0.025, 'estimator__scale_pos_weight': 7}
# param_grid = {
#     'estimator__learning_rate': [0.015, 0.025],
#     'estimator__depth': [6, 7],
#     'estimator__iterations': [300,400],
#     'estimator__scale_pos_weight': [7, 8],
#     'estimator__l2_leaf_reg': [1, 2]
# }
# Best parameters: {'estimator__depth': 7, 'estimator__iterations': 300, 'estimator__l2_leaf_reg': 2, 'estimator__learning_rate': 0.025, 'estimator__scale_pos_weight': 7}
# Best validation score: 0.69
# Test F1 score: 0.70

# Classification report on the test set:
#               precision    recall  f1-score   support

#            0       0.45      0.82      0.58        55
#            1       0.47      0.79      0.59        48
#            2       0.59      0.97      0.73        75
#            3       0.57      0.93      0.71        76
#            4       0.61      0.92      0.73        73
#            5       0.64      0.96      0.76        93

#    micro avg       0.57      0.91      0.70       420
#    macro avg       0.56      0.90      0.69       420
# weighted avg       0.57      0.91      0.70       420
#  samples avg       0.50      0.76      0.58       420

param_grid = {
    'estimator__learning_rate': [0.025],
    'estimator__depth': [7],
    'estimator__iterations': [300],
    'estimator__scale_pos_weight': [6, 7],
    'estimator__l2_leaf_reg': [2]
}


# Perform grid search
grid_search = GridSearchCV(
    catboost_model,
    param_grid,
    cv=5,
    scoring='f1_weighted',
    verbose=1,
    n_jobs=-1
)
grid_search.fit(X_train, y_train)

# Summarize results
best_params = grid_search.best_params_
best_val_score = grid_search.best_score_
y_test_pred = grid_search.best_estimator_.predict(X_test)
test_f1_score = f1_score(y_test, y_test_pred, average='weighted')

# Calculate train scores
mean_train_score = np.mean(grid_search.cv_results_['mean_train_score']) if 'mean_train_score' in grid_search.cv_results_ else None

# Display results
print("Best parameters:", best_params)
if mean_train_score is not None:
    print(f"Best cross-validation train score: {mean_train_score:.2f}")
print(f"Best validation score: {best_val_score:.2f}")
print(f"Test F1 score: {test_f1_score:.2f}")
print("\nClassification report on the test set:")
print(classification_report(y_test, y_test_pred, zero_division=0))

import joblib

# Save the best estimator from the grid search
joblib.dump(grid_search.best_estimator_, 'catboost_multioutput_model.pkl')
print("Model saved successfully.")
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# 0:	learn: 0.6817977	total: 54.2ms	remaining: 16.2s
# 0:	learn: 0.6835206	total: 54.5ms	remaining: 16.3s
# 0:	learn: 0.6832157	total: 53.9ms	remaining: 16.1s
# 0:	learn: 0.6844532	total: 56.3ms	remaining: 16.8s
# 0:	learn: 0.6806648	total: 58ms	remaining: 17.4s
# 0:	learn: 0.6807851	total: 60.6ms	remaining: 18.1s
# 0:	learn: 0.6816439	total: 67.4ms	remaining: 20.1s
# 0:	learn: 0.6826758	total: 77.4ms	remaining: 23.2s
# 0:	learn: 0.6822063	total: 68.7ms	remaining: 20.6s
# 0:	learn: 0.6838050	total: 167ms	remaining: 49.9s
# 50:	learn: 0.4216515	total: 573ms	remaining: 2.79s
# 50:	learn: 0.4032509	total: 567ms	remaining: 2.77s
# 50:	learn: 0.4157615	total: 630ms	remaining: 3.08s
# 50:	learn: 0.4265300	total: 669ms	remaining: 3.27s
# 50:	learn: 0.3997328	total: 664ms	remaining: 3.24s
# 50:	learn: 0.4237002	total: 678ms	remaining: 3.31s
# 50:	learn: 0.4090033	total: 595ms	remaining: 2.9s
# 50:	learn: 0.4137011	total: 607ms	remaining: 2.96s
# 50:	learn: 0.3993052	total: 668ms	remaining: 3.26s
# 50:	learn: 0.4181548	total: 662ms	remaining: 3.23s
# 100:	learn: 0.3035995	total: 1.02s	remaining: 2.02s
# 100:	learn: 0.3193902	total: 1.04s	remaining: 2.05s
# 100:	learn: 0.3101268	total: 1.08s	remaining: 2.14s
# 100:	learn: 0.3083465	total: 1.08s	remaining: 2.13s
# 100:	learn: 0.3035037	total: 1.03s	remaining: 2.03s
# 100:	learn: 0.3132022	total: 1.13s	remaining: 2.22s
# 100:	learn: 0.3174241	total: 1.02s	remaining: 2.02s
# 100:	learn: 0.3225965	total: 1.14s	remaining: 2.24s
# 100:	learn: 0.2948818	total: 1.09s	remaining: 2.14s
# 100:	learn: 0.3176552	total: 1.06s	remaining: 2.08s
# 150:	learn: 0.2488966	total: 1.43s	remaining: 1.41s
# 150:	learn: 0.2544575	total: 1.46s	remaining: 1.44s
# 150:	learn: 0.2580193	total: 1.51s	remaining: 1.49s
# 150:	learn: 0.2520726	total: 1.51s	remaining: 1.49s
# 150:	learn: 0.2447630	total: 1.58s	remaining: 1.56s
# 150:	learn: 0.2554898	total: 1.48s	remaining: 1.46s
# 299:	learn: 0.1020421	total: 1.98s	remaining: 0us
# 299:	learn: 0.1023219	total: 2.04s	remaining: 0us
# 299:	learn: 0.0923899	total: 2.04s	remaining: 0us
# 299:	learn: 0.0872037	total: 1.98s	remaining: 0us
# 299:	learn: 0.0844673	total: 2.07s	remaining: 0us
# 0:	learn: 0.6765010	total: 8.74ms	remaining: 2.61s
# 0:	learn: 0.6789730	total: 7.01ms	remaining: 2.1s
# 0:	learn: 0.6756684	total: 8.45ms	remaining: 2.52s
# 299:	learn: 0.0979927	total: 2.1s	remaining: 0us
# 299:	learn: 0.0954856	total: 2.12s	remaining: 0us
# 0:	learn: 0.6753238	total: 7.45ms	remaining: 2.23s
# 0:	learn: 0.6773168	total: 7.49ms	remaining: 2.24s
# 299:	learn: 0.0951455	total: 2.02s	remaining: 0us
# 0:	learn: 0.6785804	total: 8.21ms	remaining: 2.46s
# 0:	learn: 0.6777025	total: 11.2ms	remaining: 3.35s
# 0:	learn: 0.6750802	total: 10.2ms	remaining: 3.05s
# 299:	learn: 0.0955089	total: 2.1s	remaining: 0us
# 0:	learn: 0.6771725	total: 8.12ms	remaining: 2.43s
# 299:	learn: 0.0946635	total: 2.02s	remaining: 0us
# 0:	learn: 0.6769271	total: 11.5ms	remaining: 3.45s
# 50:	learn: 0.3450073	total: 285ms	remaining: 1.39s
# 50:	learn: 0.3405781	total: 309ms	remaining: 1.51s
# 50:	learn: 0.3727131	total: 317ms	remaining: 1.55s
# 50:	learn: 0.3626900	total: 293ms	remaining: 1.43s
# 50:	learn: 0.3654381	total: 321ms	remaining: 1.57s
# 50:	learn: 0.3449189	total: 320ms	remaining: 1.56s
# 50:	learn: 0.3607151	total: 313ms	remaining: 1.53s
# 50:	learn: 0.3329755	total: 316ms	remaining: 1.54s
# 50:	learn: 0.3555060	total: 333ms	remaining: 1.63s
# 50:	learn: 0.3496838	total: 320ms	remaining: 1.56s
# 100:	learn: 0.2666876	total: 617ms	remaining: 1.22s
# 100:	learn: 0.2667499	total: 626ms	remaining: 1.23s
# 100:	learn: 0.2804446	total: 641ms	remaining: 1.26s
# 100:	learn: 0.2847059	total: 618ms	remaining: 1.22s
# 100:	learn: 0.2849832	total: 639ms	remaining: 1.26s
# 100:	learn: 0.2706484	total: 631ms	remaining: 1.24s
# 100:	learn: 0.2707498	total: 649ms	remaining: 1.28s
# 100:	learn: 0.2560467	total: 649ms	remaining: 1.28s
# 100:	learn: 0.2825876	total: 653ms	remaining: 1.29s
# 100:	learn: 0.2694368	total: 630ms	remaining: 1.24s
# 150:	learn: 0.2297239	total: 952ms	remaining: 939ms
# 150:	learn: 0.2327005	total: 957ms	remaining: 945ms
# 150:	learn: 0.2190488	total: 960ms	remaining: 947ms
# 150:	learn: 0.2359459	total: 922ms	remaining: 909ms
# 150:	learn: 0.2390746	total: 942ms	remaining: 930ms
# 150:	learn: 0.2254076	total: 956ms	remaining: 943ms
# 150:	learn: 0.2289702	total: 975ms	remaining: 962ms
# 150:	learn: 0.2106347	total: 981ms	remaining: 968ms
# 150:	learn: 0.2394268	total: 970ms	remaining: 957ms
# 150:	learn: 0.2237105	total: 949ms	remaining: 937ms
# 200:	learn: 0.2020678	total: 1.25s	remaining: 615ms
# 200:	learn: 0.1977406	total: 1.29s	remaining: 635ms
# 200:	learn: 0.1862149	total: 1.3s	remaining: 643ms
# 200:	learn: 0.2011645	total: 1.28s	remaining: 629ms
# 200:	learn: 0.1987537	total: 1.3s	remaining: 642ms
# 200:	learn: 0.1991026	total: 1.3s	remaining: 643ms
# 200:	learn: 0.1882938	total: 1.29s	remaining: 638ms
# 200:	learn: 0.1868500	total: 1.3s	remaining: 642ms
# 200:	learn: 0.2020426	total: 1.31s	remaining: 645ms
# 200:	learn: 0.1848257	total: 1.28s	remaining: 631ms
# 250:	learn: 0.1584730	total: 1.63s	remaining: 317ms
# 250:	learn: 0.1677317	total: 1.62s	remaining: 316ms
# 250:	learn: 0.1708216	total: 1.59s	remaining: 310ms
# 250:	learn: 0.1699305	total: 1.63s	remaining: 318ms
# 250:	learn: 0.1721290	total: 1.61s	remaining: 315ms
# 250:	learn: 0.1723553	total: 1.62s	remaining: 317ms
# 250:	learn: 0.1596815	total: 1.63s	remaining: 318ms
# 250:	learn: 0.1636268	total: 1.62s	remaining: 316ms
# 250:	learn: 0.1782311	total: 1.63s	remaining: 318ms
# 250:	learn: 0.1624948	total: 1.61s	remaining: 315ms
# 299:	learn: 0.1385261	total: 1.95s	remaining: 0us
# 299:	learn: 0.1531862	total: 1.91s	remaining: 0us
# 299:	learn: 0.1475002	total: 1.9s	remaining: 0us
# 299:	learn: 0.1479694	total: 1.94s	remaining: 0us
# 299:	learn: 0.1481898	total: 1.93s	remaining: 0us
# 299:	learn: 0.1487027	total: 1.95s	remaining: 0us
# 0:	learn: 0.6746941	total: 5.33ms	remaining: 1.59s
# 0:	learn: 0.6739645	total: 8.49ms	remaining: 2.54s
# 0:	learn: 0.6797970	total: 6.97ms	remaining: 2.08s
# 0:	learn: 0.6780768	total: 5.92ms	remaining: 1.77s
# 0:	learn: 0.6759632	total: 7.94ms	remaining: 2.37s
# 0:	learn: 0.6777552	total: 6.1ms	remaining: 1.82s
# 299:	learn: 0.1337489	total: 1.96s	remaining: 0us
# 299:	learn: 0.1468457	total: 1.95s	remaining: 0us
# 0:	learn: 0.6768081	total: 7.27ms	remaining: 2.17s
# 299:	learn: 0.1588598	total: 1.96s	remaining: 0us
# 0:	learn: 0.6762444	total: 6.64ms	remaining: 1.99s
# 0:	learn: 0.6783261	total: 7.79ms	remaining: 2.33s
# 299:	learn: 0.1474244	total: 1.94s	remaining: 0us
# 0:	learn: 0.6759894	total: 7.46ms	remaining: 2.23s
# 50:	learn: 0.3844966	total: 303ms	remaining: 1.48s
# 50:	learn: 0.3704486	total: 309ms	remaining: 1.51s
# 50:	learn: 0.3274438	total: 318ms	remaining: 1.55s
# 50:	learn: 0.3638879	total: 314ms	remaining: 1.53s
# 50:	learn: 0.3152258	total: 324ms	remaining: 1.58s
# 50:	learn: 0.3472032	total: 338ms	remaining: 1.65s
# 50:	learn: 0.3346736	total: 327ms	remaining: 1.6s
# 50:	learn: 0.3492806	total: 323ms	remaining: 1.58s
# 50:	learn: 0.3695579	total: 345ms	remaining: 1.68s
# 50:	learn: 0.3523056	total: 323ms	remaining: 1.58s
# 100:	learn: 0.2790144	total: 633ms	remaining: 1.25s
# 100:	learn: 0.2964286	total: 640ms	remaining: 1.26s
# 100:	learn: 0.2810445	total: 637ms	remaining: 1.25s
# 100:	learn: 0.2580876	total: 656ms	remaining: 1.29s
# 100:	learn: 0.2371045	total: 661ms	remaining: 1.3s
# 100:	learn: 0.2749825	total: 670ms	remaining: 1.32s
# 100:	learn: 0.2500103	total: 668ms	remaining: 1.31s
# 100:	learn: 0.2712296	total: 649ms	remaining: 1.28s
# 100:	learn: 0.2886226	total: 670ms	remaining: 1.32s
# 100:	learn: 0.2695418	total: 647ms	remaining: 1.27s
# 150:	learn: 0.2375829	total: 947ms	remaining: 935ms
# 150:	learn: 0.2178750	total: 954ms	remaining: 941ms
# 150:	learn: 0.2448753	total: 954ms	remaining: 942ms
# 150:	learn: 0.2314041	total: 963ms	remaining: 951ms
# 150:	learn: 0.1945121	total: 983ms	remaining: 970ms
# 150:	learn: 0.2327937	total: 988ms	remaining: 974ms
# 150:	learn: 0.2286774	total: 966ms	remaining: 953ms
# 150:	learn: 0.1959645	total: 994ms	remaining: 981ms
# 150:	learn: 0.2408752	total: 985ms	remaining: 972ms
# 150:	learn: 0.2214986	total: 948ms	remaining: 935ms
# 200:	learn: 0.1871973	total: 1.26s	remaining: 621ms
# 200:	learn: 0.2012352	total: 1.26s	remaining: 621ms
# 200:	learn: 0.1928655	total: 1.27s	remaining: 628ms
# 200:	learn: 0.1963403	total: 1.28s	remaining: 630ms
# 200:	learn: 0.2042287	total: 1.3s	remaining: 640ms
# 200:	learn: 0.1634637	total: 1.3s	remaining: 639ms
# 200:	learn: 0.1995181	total: 1.28s	remaining: 629ms
# 200:	learn: 0.1626213	total: 1.32s	remaining: 651ms
# 200:	learn: 0.2074897	total: 1.27s	remaining: 627ms
# 200:	learn: 0.1892441	total: 1.27s	remaining: 625ms
# 250:	learn: 0.1646929	total: 1.56s	remaining: 305ms
# 250:	learn: 0.1639374	total: 1.59s	remaining: 310ms
# 250:	learn: 0.1686489	total: 1.58s	remaining: 309ms
# 250:	learn: 0.1645121	total: 1.61s	remaining: 314ms
# 250:	learn: 0.1788434	total: 1.62s	remaining: 316ms
# 250:	learn: 0.1387552	total: 1.63s	remaining: 319ms
# 250:	learn: 0.1721195	total: 1.59s	remaining: 312ms
# 250:	learn: 0.1337026	total: 1.64s	remaining: 321ms
# 250:	learn: 0.1780320	total: 1.6s	remaining: 312ms
# 250:	learn: 0.1626687	total: 1.58s	remaining: 308ms
# 299:	learn: 0.1458395	total: 1.89s	remaining: 0us
# 299:	learn: 0.1478781	total: 1.89s	remaining: 0us
# 299:	learn: 0.1415509	total: 1.92s	remaining: 0us
# 299:	learn: 0.1578500	total: 1.92s	remaining: 0us
# 0:	learn: 0.6757513	total: 6.33ms	remaining: 1.89s
# 299:	learn: 0.1452329	total: 1.92s	remaining: 0us
# 0:	learn: 0.6743094	total: 7.22ms	remaining: 2.16s
# 0:	learn: 0.6785421	total: 7.71ms	remaining: 2.3s
# 299:	learn: 0.1266422	total: 1.94s	remaining: 0us
# 0:	learn: 0.6776896	total: 6.86ms	remaining: 2.05s
# 0:	learn: 0.6771434	total: 7.25ms	remaining: 2.17s
# 0:	learn: 0.6753809	total: 6.55ms	remaining: 1.96s
# 299:	learn: 0.1544984	total: 1.92s	remaining: 0us
# 299:	learn: 0.1142766	total: 1.97s	remaining: 0us
# 0:	learn: 0.6771030	total: 5.39ms	remaining: 1.61s
# 299:	learn: 0.1555529	total: 1.92s	remaining: 0us
# 0:	learn: 0.6774438	total: 6.28ms	remaining: 1.88s
# 0:	learn: 0.6791178	total: 5.81ms	remaining: 1.74s
# 299:	learn: 0.1401372	total: 1.9s	remaining: 0us
# 0:	learn: 0.6765048	total: 10.1ms	remaining: 3.03s
# 50:	learn: 0.3207649	total: 299ms	remaining: 1.46s
# 50:	learn: 0.3412078	total: 305ms	remaining: 1.49s
# 50:	learn: 0.3426198	total: 302ms	remaining: 1.48s
# 50:	learn: 0.3371115	total: 316ms	remaining: 1.54s
# 50:	learn: 0.3253006	total: 317ms	remaining: 1.55s
# 50:	learn: 0.3168981	total: 327ms	remaining: 1.59s
# 50:	learn: 0.3251997	total: 313ms	remaining: 1.53s
# 50:	learn: 0.3358634	total: 329ms	remaining: 1.61s
# 50:	learn: 0.3433801	total: 338ms	remaining: 1.65s
# 50:	learn: 0.3198980	total: 333ms	remaining: 1.63s
# 100:	learn: 0.2427677	total: 617ms	remaining: 1.21s
# 100:	learn: 0.2561504	total: 628ms	remaining: 1.24s
# 100:	learn: 0.2464583	total: 651ms	remaining: 1.28s
# 100:	learn: 0.2525336	total: 655ms	remaining: 1.29s
# 100:	learn: 0.2363278	total: 631ms	remaining: 1.24s
# 100:	learn: 0.2363597	total: 649ms	remaining: 1.28s
# 100:	learn: 0.2346020	total: 634ms	remaining: 1.25s
# 100:	learn: 0.2510676	total: 644ms	remaining: 1.27s
# 100:	learn: 0.2500125	total: 655ms	remaining: 1.29s
# 100:	learn: 0.2397499	total: 654ms	remaining: 1.29s
# 150:	learn: 0.2002316	total: 912ms	remaining: 900ms
# 150:	learn: 0.2119422	total: 950ms	remaining: 938ms
# 150:	learn: 0.1887966	total: 953ms	remaining: 941ms
# 150:	learn: 0.2013569	total: 978ms	remaining: 965ms
# 150:	learn: 0.1979329	total: 982ms	remaining: 969ms
# 150:	learn: 0.1922939	total: 956ms	remaining: 943ms
# 150:	learn: 0.1893639	total: 933ms	remaining: 920ms
# 150:	learn: 0.1996481	total: 977ms	remaining: 964ms
# 150:	learn: 0.1967731	total: 983ms	remaining: 970ms
# 150:	learn: 0.1963967	total: 977ms	remaining: 964ms
# 200:	learn: 0.1668867	total: 1.25s	remaining: 614ms
# 200:	learn: 0.1790918	total: 1.27s	remaining: 627ms
# 200:	learn: 0.1682001	total: 1.29s	remaining: 638ms
# 200:	learn: 0.1607016	total: 1.3s	remaining: 642ms
# 200:	learn: 0.1569778	total: 1.27s	remaining: 626ms
# 200:	learn: 0.1567807	total: 1.29s	remaining: 637ms
# 200:	learn: 0.1595091	total: 1.26s	remaining: 620ms
# 200:	learn: 0.1636679	total: 1.3s	remaining: 641ms
# 200:	learn: 0.1638599	total: 1.31s	remaining: 644ms
# 200:	learn: 0.1631255	total: 1.31s	remaining: 644ms
# 250:	learn: 0.1498477	total: 1.57s	remaining: 306ms
# 250:	learn: 0.1422162	total: 1.59s	remaining: 310ms
# 250:	learn: 0.1433154	total: 1.62s	remaining: 317ms
# 250:	learn: 0.1295079	total: 1.59s	remaining: 310ms
# 250:	learn: 0.1291296	total: 1.6s	remaining: 312ms
# 250:	learn: 0.1307535	total: 1.63s	remaining: 319ms
# 250:	learn: 0.1376441	total: 1.57s	remaining: 307ms
# 250:	learn: 0.1355813	total: 1.63s	remaining: 319ms
# 250:	learn: 0.1369590	total: 1.63s	remaining: 318ms
# 250:	learn: 0.1406551	total: 1.62s	remaining: 316ms
# 299:	learn: 0.1237533	total: 1.89s	remaining: 0us
# 299:	learn: 0.1311876	total: 1.88s	remaining: 0us
# 299:	learn: 0.1261844	total: 1.94s	remaining: 0us
# 299:	learn: 0.1113911	total: 1.91s	remaining: 0us
# 0:	learn: 0.6745702	total: 7.45ms	remaining: 2.23s
# 0:	learn: 0.6725416	total: 5.09ms	remaining: 1.52s
# 299:	learn: 0.1101081	total: 1.94s	remaining: 0us
# 299:	learn: 0.1116147	total: 1.91s	remaining: 0us
# 0:	learn: 0.6722483	total: 8.57ms	remaining: 2.56s
# 0:	learn: 0.6707150	total: 8.01ms	remaining: 2.4s
# 0:	learn: 0.6728100	total: 7ms	remaining: 2.09s
# 0:	learn: 0.6701509	total: 5.16ms	remaining: 1.54s
# 299:	learn: 0.1226919	total: 1.9s	remaining: 0us
# 0:	learn: 0.6706342	total: 5.46ms	remaining: 1.63s
# 299:	learn: 0.1206438	total: 1.93s	remaining: 0us
# 299:	learn: 0.1180694	total: 1.96s	remaining: 0us
# 0:	learn: 0.6727209	total: 7.16ms	remaining: 2.14s
# 0:	learn: 0.6722684	total: 6.71ms	remaining: 2.01s
# 299:	learn: 0.1261616	total: 1.94s	remaining: 0us
# 0:	learn: 0.6701890	total: 6.71ms	remaining: 2s
# 50:	learn: 0.3235907	total: 307ms	remaining: 1.5s
# 50:	learn: 0.3004294	total: 318ms	remaining: 1.55s
# 50:	learn: 0.2966479	total: 312ms	remaining: 1.52s
# 50:	learn: 0.3080970	total: 302ms	remaining: 1.47s
# 50:	learn: 0.2888559	total: 303ms	remaining: 1.48s
# 50:	learn: 0.2769842	total: 326ms	remaining: 1.59s
# 50:	learn: 0.2829783	total: 310ms	remaining: 1.51s
# 50:	learn: 0.3047160	total: 330ms	remaining: 1.61s
# 50:	learn: 0.2957381	total: 334ms	remaining: 1.63s
# 50:	learn: 0.2780336	total: 329ms	remaining: 1.61s
# 100:	learn: 0.2431756	total: 627ms	remaining: 1.24s
# 100:	learn: 0.2535663	total: 636ms	remaining: 1.25s
# 100:	learn: 0.2292898	total: 636ms	remaining: 1.25s
# 100:	learn: 0.2178171	total: 627ms	remaining: 1.24s
# 100:	learn: 0.2313782	total: 640ms	remaining: 1.26s
# 100:	learn: 0.2109761	total: 663ms	remaining: 1.31s
# 100:	learn: 0.2240242	total: 643ms	remaining: 1.27s
# 100:	learn: 0.2399589	total: 646ms	remaining: 1.27s
# 100:	learn: 0.2256093	total: 664ms	remaining: 1.31s
# 100:	learn: 0.2165515	total: 642ms	remaining: 1.26s
# 150:	learn: 0.2079788	total: 956ms	remaining: 943ms
# 150:	learn: 0.2102561	total: 962ms	remaining: 949ms
# 150:	learn: 0.1841242	total: 952ms	remaining: 939ms
# 150:	learn: 0.1907249	total: 963ms	remaining: 950ms
# 150:	learn: 0.1884754	total: 982ms	remaining: 969ms
# 150:	learn: 0.1771172	total: 979ms	remaining: 966ms
# 150:	learn: 0.1869774	total: 959ms	remaining: 946ms
# 150:	learn: 0.1999523	total: 967ms	remaining: 955ms
# 150:	learn: 0.1888402	total: 984ms	remaining: 971ms
# 150:	learn: 0.1811030	total: 961ms	remaining: 948ms
# 200:	learn: 0.1838035	total: 1.29s	remaining: 635ms
# 200:	learn: 0.1816519	total: 1.29s	remaining: 638ms
# 200:	learn: 0.1520403	total: 1.27s	remaining: 625ms
# 200:	learn: 0.1581016	total: 1.29s	remaining: 634ms
# 200:	learn: 0.1612612	total: 1.3s	remaining: 639ms
# 200:	learn: 0.1561855	total: 1.32s	remaining: 648ms
# 200:	learn: 0.1649263	total: 1.28s	remaining: 632ms
# 200:	learn: 0.1746004	total: 1.29s	remaining: 637ms
# 200:	learn: 0.1642911	total: 1.34s	remaining: 659ms
# 200:	learn: 0.1560920	total: 1.32s	remaining: 651ms
# 250:	learn: 0.1340233	total: 1.6s	remaining: 313ms
# 250:	learn: 0.1659051	total: 1.64s	remaining: 320ms
# 250:	learn: 0.1614348	total: 1.65s	remaining: 322ms
# 250:	learn: 0.1412780	total: 1.64s	remaining: 319ms
# 250:	learn: 0.1383285	total: 1.65s	remaining: 322ms
# 250:	learn: 0.1443702	total: 1.68s	remaining: 328ms
# 250:	learn: 0.1506950	total: 1.66s	remaining: 324ms
# 250:	learn: 0.1503536	total: 1.65s	remaining: 322ms
# 250:	learn: 0.1456703	total: 1.67s	remaining: 326ms
# 250:	learn: 0.1351783	total: 1.64s	remaining: 321ms
# 299:	learn: 0.1206256	total: 1.91s	remaining: 0us
# 299:	learn: 0.1562014	total: 1.96s	remaining: 0us
# 299:	learn: 0.1488219	total: 1.97s	remaining: 0us
# 299:	learn: 0.1262611	total: 1.96s	remaining: 0us
# Best parameters: {'estimator__depth': 7, 'estimator__iterations': 300, 'estimator__l2_leaf_reg': 2, 'estimator__learning_rate': 0.025, 'estimator__scale_pos_weight': 7}
# Best validation score: 0.69
# Test F1 score: 0.70
#
# Classification report on the test set:
#               precision    recall  f1-score   support
#
#            0       0.45      0.82      0.58        55
#            1       0.47      0.79      0.59        48
#            2       0.59      0.97      0.73        75
#            3       0.57      0.93      0.71        76
#            4       0.61      0.92      0.73        73
#            5       0.64      0.96      0.76        93
#
#    micro avg       0.57      0.91      0.70       420
#    macro avg       0.56      0.90      0.69       420
# weighted avg       0.57      0.91      0.70       420
#  samples avg       0.50      0.76      0.58       420

# %%
import joblib

# Save the best estimator from the grid search
joblib.dump(grid_search.best_estimator_, 'catboost_multioutput_model.pkl')
print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
import pandas as pd
import joblib
from sklearn.metrics import accuracy_score, classification_report

# Step 1: Load the trained model
print("Loading the trained model...")
model = joblib.load('catboost_multioutput_model.pkl')

# Step 2: Load the new dataset
print("Loading the dataset...")
data = pd.read_csv('xydata_2023winter.csv')

# Step 3: Define the feature and target columns
features = [
    "Time_Period", "Stn Press (kPa)", "Dew Point Temp (°C)", "Rel Hum (%)",
    "Visibility (km)", "Temp (°C)", "Wind Dir (10s deg)", "Wind Spd (km/h)",
    "C0D-1HA", "C0D-2HA", "C0D-4HA",  # Cluster 0 historical features
    "C1D-1HA", "C1D-2HA", "C1D-4HA",  # Cluster 1 historical features
    "C2D-1HA", "C2D-2HA", "C2D-3HA",  # Cluster 2 historical features
    "C3D-1HA", "C4D-1HA", "C4D-2HA", "C5D-1HA"  # Other cluster features
]

target_columns = [f"Cluster{i}" for i in range(6)]

# Step 4: Ensure all features are present in the dataset
for feature in features:
    if feature not in data.columns:
        data[feature] = 0  # Add missing features with a default value of 0

# Step 5: Extract the features (X) and target (y)
X = data[features]
y_true = data[target_columns]

# Step 6: Generate predictions
print("Making predictions...")
y_pred = model.predict(X)

# Step 7: Evaluate predictions
# Rename clusters for simplicity
y_pred_df = pd.DataFrame(y_pred, columns=[f"C{i}" for i in range(6)])
y_true.columns = [f"C{i}" for i in range(6)]

# Calculate the accuracy score (mean accuracy across all clusters)
cluster_accuracies = []
for col in y_pred_df.columns:
    cluster_accuracy = accuracy_score(y_true[col], y_pred_df[col])
    cluster_accuracies.append(cluster_accuracy)
overall_accuracy = sum(cluster_accuracies) / len(cluster_accuracies)

print(f"Overall Test Set Accuracy Score (Average of All Clusters): {overall_accuracy:.2f}")

# Display a detailed classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred_df, target_names=y_pred_df.columns, zero_division=0))

# Step 8: Show a comparison of predictions and true labels for the first 5 examples
print("\nFirst 5 Predictions vs. True Labels:")

# Concatenate predictions and true values for comparison
comparison = pd.concat(
    [y_pred_df.head(5), y_true.head(5).reset_index(drop=True)],
    axis=1,
    keys=["Predicted", "True"]
)

# Format and display predictions and true labels side by side
separator = "\n" + "-" * 50 + "\n"
formatted_output = ""

for index, row in comparison.iterrows():
    formatted_output += f"Row {index + 1}{separator}"
    for col in y_pred_df.columns:
        formatted_output += f"{col}: Predicted={row[('Predicted', col)]}, True={row[('True', col)]}\n"
    formatted_output += separator

print(formatted_output)
# Out:
# Loading the trained model...
# Loading the dataset...
# Making predictions...
# Overall Test Set Accuracy Score (Average of All Clusters): 0.63
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           C0       0.50      0.87      0.63       195
#           C1       0.41      0.70      0.51       155
#           C2       0.61      0.97      0.75       257
#           C3       0.60      0.94      0.73       256
#           C4       0.59      0.93      0.72       244
#           C5       0.63      0.97      0.76       283
#
#    micro avg       0.57      0.92      0.70      1390
#    macro avg       0.55      0.90      0.68      1390
# weighted avg       0.57      0.92      0.70      1390
#  samples avg       0.50      0.77      0.57      1390
#
#
# First 5 Predictions vs. True Labels:
# Row 1
# --------------------------------------------------
# C0: Predicted=1, True=1
# C1: Predicted=0, True=1
# C2: Predicted=1, True=1
# C3: Predicted=1, True=0
# C4: Predicted=1, True=1
# C5: Predicted=1, True=0
#
# --------------------------------------------------
# Row 2
# --------------------------------------------------
# C0: Predicted=1, True=0
# C1: Predicted=0, True=0
# C2: Predicted=1, True=1
# C3: Predicted=1, True=1
# C4: Predicted=1, True=1
# C5: Predicted=1, True=1
#
# --------------------------------------------------
# Row 3
# --------------------------------------------------
# C0: Predicted=1, True=0
# C1: Predicted=0, True=0
# C2: Predicted=1, True=1
# C3: Predicted=1, True=1
# C4: Predicted=1, True=1
# C5: Predicted=1, True=1
#
# --------------------------------------------------
# Row 4
# --------------------------------------------------
# C0: Predicted=0, True=0
# C1: Predicted=0, True=0
# C2: Predicted=1, True=0
# C3: Predicted=1, True=0
# C4: Predicted=0, True=0
# C5: Predicted=1, True=1
#
# --------------------------------------------------
# Row 5
# --------------------------------------------------
# C0: Predicted=1, True=1
# C1: Predicted=0, True=0
# C2: Predicted=1, True=0
# C3: Predicted=1, True=0
# C4: Predicted=1, True=1
# C5: Predicted=1, True=1
#
# --------------------------------------------------

# %%
# Load the saved model
loaded_model = joblib.load('catboost_multioutput_model.pkl')
print("Model loaded successfully.")

# Make predictions with new data (replace `new_data` with your new input data)
new_data = pd.DataFrame({
    # Replace with your new data features
    "Time_Period": [1],
    "Stn Press (kPa)": [100.5],
    "Dew Point Temp (°C)": [5.0],
    "Rel Hum (%)": [60],
    "Visibility (km)": [10],
    "Temp (°C)": [15],
    "Wind Dir (10s deg)": [3],
    "Wind Spd (km/h)": [5],
    "C0D-1HA": [0.1],
    "C0D-2HA": [0.2],
    "C0D-4HA": [0.3],
    "C1D-1HA": [0.1],
    "C1D-2HA": [0.2],
    "C1D-4HA": [0.3],
    "C2D-1HA": [0.1],
    "C2D-2HA": [0.2],
    "C2D-3HA": [0.3],
    "C3D-1HA": [0.1],
    "C4D-1HA": [0.2],
    "C4D-2HA": [0.3],
    "C5D-1HA": [0.1],
})

predictions = loaded_model.predict(new_data)
print("Predictions on new data:")
print(predictions)
# Out:
# Model loaded successfully.
# Predictions on new data:
# [[1 0 1 1 1 1]]
